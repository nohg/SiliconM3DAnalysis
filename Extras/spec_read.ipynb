# %%
from os.path import dirname, join as pjoin
import scipy.io as sio
from scipy.io import readsav
import matplotlib.pyplot as plt

# %%
# data_dir = pjoin(dirname(sio.__file__))#, 'tests', 'data')
# sav_fname = pjoin('iag_sun.sav')
# sav_data = readsav(sav_fname)
sav_fname = pjoin('../data/spectra/1631885174310_iag_sun_Si.sav')
sav_data = readsav(sav_fname)

# %%
print(sav_data.keys())
# Out:
# dict_keys(['iag_sun'])

# %%
sav_data['iag_sun']
# Out:
# rec.array([(array([1.  , 0.99, 0.98, 0.95, 0.9 , 0.8 , 0.7 , 0.6 , 0.5 , 0.4 , 0.3 ,
#                   0.2 ], dtype=float32), array([array([5637.18050195, 5637.18418762, 5637.18787328, ..., 7238.1892601 ,
#                          7238.19294575, 7238.1966314 ])                                  ,
#                   array([5637.1811145 , 5637.18478592, 5637.18845733, ..., 7238.18962378,
#                          7238.19329518, 7238.19696658])                                  ,
#                   array([5637.18276663, 5637.18645467, 5637.19014271, ..., 7238.19135819,
#                          7238.19504622, 7238.19873425])                                  ,
#                   array([5637.18124988, 5637.18493665, 5637.18862342, ..., 7238.19280299,
#                          7238.19648975, 7238.20017651])                                  ,
#                   array([5637.18098225, 5637.18467478, 5637.18836731, ..., 7238.19077795,
#                          7238.19447047, 7238.198163  ])                                  ,
#                   array([5637.18191059, 5637.18558892, 5637.18926724, ..., 7238.19142579,
#                          7238.19510411, 7238.19878242])                                  ,
#                   array([5637.18060612, 5637.18425102, 5637.18789591, ..., 7238.19179047,
#                          7238.19543536, 7238.19908025])                                  ,
#                   array([5637.18187043, 5637.18555388, 5637.18923732, ..., 7238.19182643,
#                          7238.19550986, 7238.1991933 ])                                  ,
#                   array([5637.18289031, 5637.18655984, 5637.19022936, ..., 7238.19035618,
#                          7238.1940257 , 7238.19769521])                                  ,
#                   array([5637.18159465, 5637.18526087, 5637.18892708, ..., 7238.18970462,
#                          7238.19337083, 7238.19703703])                                  ,
#                   array([5637.18333491, 5637.18699488, 5637.19065485, ..., 7238.19241844,
#                          7238.1960784 , 7238.19973837])                                  ,
#                   array([5637.18216473, 5637.18581378, 5637.18946283, ..., 7238.19266593,
#                          7238.19631497, 7238.19996401])                                  ],
#                  dtype=object), array([array([0.91207475, 0.92227516, 0.93153505, ..., 0.99451827, 0.99451719,
#                          0.99451611])                                                    ,
#                   array([0.91277093, 0.9225923 , 0.93053086, ..., 0.994659  , 0.9946684 ,
#                          0.99467779])                                                    ,
#                   array([0.91767428, 0.92994696, 0.94041895, ..., 0.99485371, 0.99486156,
#                          0.99486941])                                                    ,
#                   array([0.91193533, 0.92200299, 0.92990031, ..., 0.9951228 , 0.99513558,
#                          0.99514835])                                                    ,
#                   array([0.90584613, 0.91716178, 0.92714617, ..., 0.99683746, 0.99685196,
#                          0.99686645])                                                    ,
#                   array([0.90168265, 0.91212061, 0.92258069, ..., 0.99408873, 0.9941043 ,
#                          0.99411987])                                                    ,
#                   array([0.89873383, 0.90919503, 0.91983792, ..., 0.99235468, 0.99236508,
#                          0.99237548])                                                    ,
#                   array([0.89615102, 0.90718659, 0.91691924, ..., 0.99353054, 0.99353635,
#                          0.99354216])                                                    ,
#                   array([0.89585022, 0.90677356, 0.91748705, ..., 0.99583898, 0.99586364,
#                          0.9958883 ])                                                    ,
#                   array([0.88253434, 0.89381593, 0.90463034, ..., 0.99349153, 0.99351263,
#                          0.99353374])                                                    ,
#                   array([0.88302415, 0.89523408, 0.90656444, ..., 0.99433475, 0.9943487 ,
#                          0.99436264])                                                    ,
#                   array([0.87904597, 0.89216885, 0.90349174, ..., 0.99384581, 0.99387469,
#                          0.99390357])                                                    ],
#                  dtype=object))                                                                                        ],
#           dtype=[(('mu', 'MU'), 'O'), (('wave', 'WAVE'), 'O'), (('flux', 'FLUX'), 'O')])

# %%
fig, ax = plt.subplots(figsize=(40,10))
lam = sav_data['iag_sun'].wave[0][0]
flux = sav_data['iag_sun'].flux[0][0]

# ax.set_xlim(7000, 7300)
# ax.set_xlim(6750, 6800)

plt.plot(lam, flux, linestyle='none', marker='.')
plt.xlim(5794,5796)
# Out:
# (5794.0, 5796.0)

# %%
sav_data['iag_sun'].wave[0].shape
# Out:
# (12,)
